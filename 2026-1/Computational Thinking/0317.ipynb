# %%
a = 20
b = 30
c = a+b
print(c)
# Out:
# 50

# %%
x=30
print(x)
print(type(x))
# Out:
# 30
# <class 'int'>

# %%
x=3.3764
y=6/2
print(x,y)
print(type(x),type(y))
# Out:
# 3.3764 3.0
# <class 'float'> <class 'float'>

# %%
a='x'
b='I am ok.'
c="ㅎㅇ"
print(a)
print(b)
print(c)
print(type(a),type(b),type(c))
# Out:
# 'ㅎㅇ'

# %%
a=30
b='30'
print(a)
print(b)
print(type(a),type(b))
# Out:
# 30
# 30
# <class 'int'> <class 'str'>

# %%
c = 10>20
print(c)
print(type(a))
# Out:
# False
# <class 'bool'>

# %%
x=10%3
print(x)
y=7//3
print(y)
# Out:
# 1
# 2

# %%
x=10
x +=20
x
# Out:
# 30

# %%
hello = 'ㅎ2'*5
hello
# Out:
# 'ㅎ2ㅎ2ㅎ2ㅎ2ㅎ2'

# %%
a = '너무 춥고 배가 고프다.'
b = len(a)
b
# Out:
# 13

# %%
name = '박민경'
greet = name + '님 맛있는 음식을 드릴게요!'
greet
# Out:
# '박민경님 맛있는 음식을 드릴게요!'

# %%
eng = 80
result = '영어점수:' + eng +'점'
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 eng = 80
# ----> 2 result = '영어점수:' + eng +'점'
#       3 result
#
# TypeError: can only concatenate str (not "int") to str

# %%
eng = 80
result = '영어점수:' + str(eng) +'점'
result
# Out:
# '영어점수:80점'

# %%
eng = 80
result = f'영어점수: {eng}점'
result
# Out:
# '영어점수: 80점'

# %%
a=2002
b=8
c=13
print(a,b,c,sep='-')
# Out:
# 2002-8-13

# %%
a='hi!'
b='hello'

print(a)
print(b)

print('\n\n')
print(a,end='')
print(b)
# Out:
# hi!
# hello
#
#
#
# hi!hello

# %%
name = input('insult your name pls:')
print(f'Welcome, {name}!')
# Out:
# Welcome, minkyung!

# %%
a = int(input('insult first value:'))
b = int(input('insult second value:'))

a+b
# Out:
# 7

# %%
INCH = float(input('inch:'))
CM = INCH*2.54
print(f'result:{CM:.1f}cm')
#f'{변수:.자릿수}' 는 :자릿수까지 반올림해서 표기
# Out:
# result:7.62cm
