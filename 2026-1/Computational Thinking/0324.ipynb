# %%
x = int(input("Enter a number: "))

if x > 0:
    print("The number is positive.")
else:
    print("The number is not positive or 0.")
# Out:
# The number is positive.

# %%
age = int(input("Enter your age: "))
pay = '3000 won'

if age >= 65:
    pay = 'free'

print(f"The entrance fee is {pay}.")
# Out:
# The entrance fee is 3000 won.

# %%
height = int(input("Enter your height in cm: "))
msg = "You are tall enough to ride the roller coaster."
if height < 120:
    msg = "You are not tall enough to ride the roller coaster."

print(msg)
# Out:
# You are tall enough to ride the roller coaster.

# %%
answer = '12345'
password = input("Enter the password: ")

if password == answer:
    print("Access granted.")
else:
    print("Access denied.")
# Out:
# Access denied.

# %%
age = int(input("Enter your age: "))
pay = '3000 won'

if age >= 65 or age < 7:
    pay = 'free'

print(f"The entrance fee is {pay}.")
# Out:
# The entrance fee is free.

# %%
name = input("Enter your name: ")
if not name:
    print("You did not enter a name.")
else:
    print(f"name: {name}")
# Out:
# name: minky

# %%
char = input("Enter a character: ")
if char =='A' or char == 'a' or char == 'E' or char == 'e' or char == 'I' or char == 'i' or char == 'O' or char == 'o' or char == 'U' or char == 'u':
    print(f'{char} is a vowel.')
else:
    print(f'{char} is a consonant.')
# Out:
# a is a vowel.

# %%
score = int(input("Enter your score: "))

if score >= 90:
    grade = 'A' 
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
elif score >= 60:
    grade = 'D'
else:
    grade = 'F'

print(f"Your score is {score}.")
print(f"Your grade is {grade}.")
# Out:
# Your score is 100.
# Your grade is A.

# %%
buy = int(input("Enter the amount of your purchase: "))

if buy >= 10000 and buy <50000:
    rate = 5
elif buy >= 50000 and buy < 300000:
    rate = 7.5
elif buy >= 300000 :
    rate = 10
else:
    rate = 0

discount = buy * rate / 100
pay = buy - discount
print(f"Your purchase amount is {buy} won.")
print(f"Your discount rate is {rate:.1f}%.")
print(f"Your discount is {discount:.0f} won.")      
print(f"You need to pay {pay:.0f} won.")
# Out:
# Your purchase amount is 60000 won.
# Your discount rate is 7.5%.
# Your discount is 4500 won.
# You need to pay 55500 won.

# %%
for x in range(5):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
sum = 0
for i in range(1, 11):
    sum += i
    print(f"value of i:{i}, sum:{sum}.")
# Out:
# value of i:1, sum:1.
# value of i:2, sum:3.
# value of i:3, sum:6.
# value of i:4, sum:10.
# value of i:5, sum:15.
# value of i:6, sum:21.
# value of i:7, sum:28.
# value of i:8, sum:36.
# value of i:9, sum:45.
# value of i:10, sum:55.

# %%
for i in range(4):
    print(i,end=' ')
print()

for i in range(1,8):
    print(i,end=' ')
print()

for i in range(1, 10, 2):
    print(i,end=' ')   
print()

for i in range(10, 0, -2):
    print(i,end=' ')    
print()
# Out:
# 0 1 2 3
# 1 2 3 4 5 6 7
# 1 3 5 7 9
# 10 8 6 4 2

# %%
sum = 0
for i in range(1, 101):
    if i %3==0:
        print(i,end = ' ')
        sum += i

print('\n','-'*50)
print(f"The sum of multiples of 3 is {sum}.")
# Out:
# 3 6 9 12 15 18 21 24 27 30 33 36 39 42 45 48 51 54 57 60 63 66 69 72 75 78 81 84 87 90 93 96 99
#  --------------------------------------------------
# The sum of multiples of 3 is 1683.

# %%
word = input("Enter a sentence: ")

for x in word:
    print(x)
# Out:
# i
#
# w
# a
# n
# t
#
# t
# o
#
# g
# o
#
# h
# o
# m
# e

# %% [markdown]
# #세 수 중 큰수 찾기

# %%
first = int(input("Enter the first number: "))
second = int(input("Enter the second number: "))    
third = int(input("Enter the third number: "))
if first >= second and first >= third:
    largest = first
elif second >= first and second >= third:
    largest = second
else:
    largest = third

print(f"The largest number is {largest}.")
# Out:
# The largest number is 4.
